# %%
import pandas as pd

# %%
file = pd.read_csv("typing.csv")
df= pd.DataFrame(file)

# %%
hits = df.columns.to_list()

# %%
len(hits)
# Out:
# 24

# %%
df.isna()
# Out:
#        _id   isPb    wpm    acc  rawWpm  consistency  charStats   mode  mode2  \
# 0    False   True  False  False   False        False      False  False  False
# 1    False   True  False  False   False        False      False  False  False
# 2    False   True  False  False   False        False      False  False  False
# 3    False   True  False  False   False        False      False  False  False
# 4    False   True  False  False   False        False      False  False  False
# ..     ...    ...    ...    ...     ...          ...        ...    ...    ...
# 446  False   True  False  False   False        False      False  False  False
# 447  False   True  False  False   False        False      False  False  False
# 448  False   True  False  False   False        False      False  False  False
# 449  False   True  False  False   False        False      False  False  False
# 450  False  False  False  False   False        False      False  False  False
#
#      quoteLength  ...  punctuation  numbers  language  funbox  difficulty  \
# 0           True  ...        False    False     False   False       False
# 1           True  ...        False    False     False   False       False
# 2           True  ...        False    False     False   False       False
# 3           True  ...        False    False     False   False       False
# 4           True  ...        False    False     False   False       False
# ..           ...  ...          ...      ...       ...     ...         ...
# 446        False  ...        False    False     False   False       False
# 447        False  ...        False    False     False   False       False
# 448        False  ...        False    False     False   False       False
# 449        False  ...        False    False     False   False       False
# 450        False  ...        False    False     False   False       False
#
#      lazyMode  blindMode  bailedOut  tags  timestamp
# 0       False      False      False  True      False
# 1       False      False      False  True      False
# 2       False      False      False  True      False
# 3       False      False      False  True      False
# 4       False      False      False  True      False
# ..        ...        ...        ...   ...        ...
# 446     False      False      False  True      False
# 447     False      False      False  True      False
# 448     False      False      False  True      False
# 449     False      False      False  True      False
# 450     False      False      False  True      False
#
# [451 rows x 24 columns]

# %%
df.isna()
# Out:
#        _id   isPb    wpm    acc  rawWpm  consistency  charStats   mode  mode2  \
# 0    False   True  False  False   False        False      False  False  False
# 1    False   True  False  False   False        False      False  False  False
# 2    False   True  False  False   False        False      False  False  False
# 3    False   True  False  False   False        False      False  False  False
# 4    False   True  False  False   False        False      False  False  False
# ..     ...    ...    ...    ...     ...          ...        ...    ...    ...
# 446  False   True  False  False   False        False      False  False  False
# 447  False   True  False  False   False        False      False  False  False
# 448  False   True  False  False   False        False      False  False  False
# 449  False   True  False  False   False        False      False  False  False
# 450  False  False  False  False   False        False      False  False  False
#
#      quoteLength  ...  punctuation  numbers  language  funbox  difficulty  \
# 0           True  ...        False    False     False   False       False
# 1           True  ...        False    False     False   False       False
# 2           True  ...        False    False     False   False       False
# 3           True  ...        False    False     False   False       False
# 4           True  ...        False    False     False   False       False
# ..           ...  ...          ...      ...       ...     ...         ...
# 446        False  ...        False    False     False   False       False
# 447        False  ...        False    False     False   False       False
# 448        False  ...        False    False     False   False       False
# 449        False  ...        False    False     False   False       False
# 450        False  ...        False    False     False   False       False
#
#      lazyMode  blindMode  bailedOut  tags  timestamp
# 0       False      False      False  True      False
# 1       False      False      False  True      False
# 2       False      False      False  True      False
# 3       False      False      False  True      False
# 4       False      False      False  True      False
# ..        ...        ...        ...   ...        ...
# 446     False      False      False  True      False
# 447     False      False      False  True      False
# 448     False      False      False  True      False
# 449     False      False      False  True      False
# 450     False      False      False  True      False
#
# [451 rows x 24 columns]

# %%
df.fillna({
  "isPb": False,
  "quoteLength": 0,
  })
# Out:
# /tmp/ipykernel_25998/1620874303.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna({
#                           _id   isPb    wpm    acc  rawWpm  consistency  \
# 0    66b78937bbf6f4795f0f506a  False  71.90  93.00   79.89        82.97
# 1    66b78333bbf6f4795f0f1714  False  75.95  93.46   85.55        84.76
# 2    66b77394bbf6f4795f0e7c2c  False  77.59  97.12   83.19        75.60
# 3    66b77361bbf6f4795f0e7a2d  False  62.34  92.78   77.52        74.21
# 4    66b77312bbf6f4795f0e7742  False  78.39  97.17   84.79        89.08
# ..                        ...    ...    ...    ...     ...          ...
# 446  628ed5c4ad7422b58f450eec  False  46.40  92.91   46.40        62.08
# 447  628ed44bad7422b58f416c32  False  38.00  90.27   40.40        57.40
# 448  628ed426ad7422b58f416b2c  False  43.20  91.87   44.40        64.75
# 449  628ed3fead7422b58f4169fb  False  39.20  90.18   39.20        52.20
# 450  628ec6b2ad7422b58f3650d8   True  48.80  99.19   48.80        70.90
#
#      charStats  mode  mode2  quoteLength  ...  punctuation  numbers  language  \
# 0     90;4;1;0  time     15          0.0  ...        False    False   english
# 1     95;4;1;1  time     15          0.0  ...        False    False   english
# 2     97;2;0;1  time     15          0.0  ...        False    False   english
# 3     78;3;0;3  time     15          0.0  ...        False    False   english
# 4     98;2;0;0  time     15          0.0  ...        False    False   english
# ..         ...   ...    ...          ...  ...          ...      ...       ...
# 446  116;0;0;0  time     30         -1.0  ...        False    False   english
# 447   95;1;0;0  time     30         -1.0  ...        False    False   english
# 448  108;1;0;0  time     30         -1.0  ...        False    False   english
# 449   98;0;0;0  time     30         -1.0  ...        False    False   english
# 450  122;0;0;0  time     30         -1.0  ...        False    False   english
#
#      funbox  difficulty  lazyMode blindMode bailedOut tags      timestamp
# 0      none      normal     False     False     False  NaN  1723304246029
# 1      none      normal     False     False     False  NaN  1723302705099
# 2      none      normal     False     False     False  NaN  1723298707430
# 3      none      normal     False     False     False  NaN  1723298656912
# 4      none      normal     False     False     False  NaN  1723298578175
# ..      ...         ...       ...       ...       ...  ...            ...
# 446    none      normal     False     False     False  NaN  1653528004000
# 447    none      normal     False     False     False  NaN  1653527627000
# 448    none      normal     False     False     False  NaN  1653527590000
# 449    none      normal     False     False     False  NaN  1653527550000
# 450    none      normal     False     False     False  NaN  1653524146000
#
# [451 rows x 24 columns]

# %%
# df.drop(columns=["tags", "isPb"], inplace=True )

# %%
df["timestamp"] =  pd.to_datetime(df["timestamp"], unit="ns")

# %%
df.timestamp.head(5)
# Out:
# 0   2024-08-10 15:37:26.029
# 1   2024-08-10 15:11:45.099
# 2   2024-08-10 14:05:07.430
# 3   2024-08-10 14:04:16.912
# 4   2024-08-10 14:02:58.175
# Name: timestamp, dtype: datetime64[ns]

# %%
# df.difficulty.unique()
# df.funbox.unique()
# df.language.unique()
# df.charStats.unique() # correct/incorrect/extra/missed 
# df["mode"].unique()
# df._id
# df.dtypes

# %%
dtype_names = [
]

import pandas.api.types as ptypes

ALLOWED_TYPES = [
    'bool',
    'category',
    'complex64',
    'complex128',
    'datetime64',
    'datetime64[ns]',
    'datetime64[ns, UTC]',
    'float16',
    'float32',
    'float64',
    'int8',
    'int16',
    'int32',
    'int64',
    'object',
    'string',
    'timedelta',
    'timedelta64',
    'uint8',
    'uint16',
    'uint32',
    'uint64',

]

def switchTarget(dataframe, column, dtype):
  try:

    if dtype in ALLOWED_TYPES:
      dataframe[column] = dataframe[column].astype(dtype)
    else:
      raise Exception(f"{dtype} is not an acceptable pandas type")
  except Exception as error:
    raise error

# %% [markdown]
# ## Data types to change
#
# column names:
#   - [x] difficulty  ( object -> enum/string )
#   - [x] funbox ( object -> string )
#   - [x] language ( object -> string )
#   - [x] mode (object -> enum/string)
#   - [x] _id (onject -> uuid/string)
#   - [ ] charStats (object -> [correct, incorrect, extra, missed] | make them individual columns).

# %%
# df.difficulty.unique()
# df.funbox.unique()
# df.language.unique()
# df.charStats.unique() # correct/incorrect/extra/missed 
# df["mode"].unique()
# df._id


dtype_hits = {
    "difficulty": "string",
    "funbox": "string",
    "language": "string",
    "mode": "string",
    "_id": "string"
}


for __hit__, __type__ in dtype_hits.items():
  switchTarget(
    dataframe=df,
    column=__hit__,
    dtype=__type__
  )

df.dtypes
# Out:
# _id                      string[python]
# wpm                             float64
# acc                             float64
# rawWpm                          float64
# consistency                     float64
# charStats                        object
# mode                     string[python]
# mode2                             int64
# quoteLength                     float64
# restartCount                      int64
# testDuration                    float64
# afkDuration                       int64
# incompleteTestSeconds           float64
# punctuation                        bool
# numbers                            bool
# language                 string[python]
# funbox                   string[python]
# difficulty               string[python]
# lazyMode                           bool
# blindMode                          bool
# bailedOut                          bool
# timestamp                datetime64[ns]
# dtype: object

# %% [markdown]
# ## Spliting the values in the charstat column to individual columns
#
#
# #### New columns
# - correct
# - incorrect
# - extra (I think these are the extra characters on each word?!)
# - missed (the missed key/charcter on each word). -> great to know my weak fingers and to work on them

# %%
df.charStats.head(5)
# Out:
# 0    90;4;1;0
# 1    95;4;1;1
# 2    97;2;0;1
# 3    78;3;0;3
# 4    98;2;0;0
# Name: charStats, dtype: object

# %%
def cleanCharSets():
    try:
        # Create new columns if they do not already exist
        for col in ['correct', 'incorrect', 'extra', 'missed']:
            if col not in df.columns:
                df[col] = None
        
        # Iterate over each row
        for index, row in df.iterrows():
            target = row['charStats']
            splits = target.split(";")
            
            # Ensure splits have the expected length
            if len(splits) == 4:
                correct, incorrect, extra, missed = splits

                # Populate the DataFrame with each value
                df.at[index, 'correct'] = correct
                df.at[index, 'incorrect'] = incorrect
                df.at[index, 'extra'] = extra
                df.at[index, 'missed'] = missed

        return df
    except Exception as error:
        raise error

# %%
new_df = cleanCharSets()
new_df.head(5)
# Out:
#                         _id    wpm    acc  rawWpm  consistency charStats  \
# 0  66b78937bbf6f4795f0f506a  71.90  93.00   79.89        82.97  90;4;1;0
# 1  66b78333bbf6f4795f0f1714  75.95  93.46   85.55        84.76  95;4;1;1
# 2  66b77394bbf6f4795f0e7c2c  77.59  97.12   83.19        75.60  97;2;0;1
# 3  66b77361bbf6f4795f0e7a2d  62.34  92.78   77.52        74.21  78;3;0;3
# 4  66b77312bbf6f4795f0e7742  78.39  97.17   84.79        89.08  98;2;0;0
#
#    mode  mode2  quoteLength  restartCount  ...  funbox  difficulty  lazyMode  \
# 0  time     15          NaN             8  ...    none      normal     False
# 1  time     15          NaN             5  ...    none      normal     False
# 2  time     15          NaN             0  ...    none      normal     False
# 3  time     15          NaN             5  ...    none      normal     False
# 4  time     15          NaN             0  ...    none      normal     False
#
#    blindMode  bailedOut               timestamp correct incorrect  extra  \
# 0      False      False 2024-08-10 15:37:26.029      90         4      1
# 1      False      False 2024-08-10 15:11:45.099      95         4      1
# 2      False      False 2024-08-10 14:05:07.430      97         2      0
# 3      False      False 2024-08-10 14:04:16.912      78         3      0
# 4      False      False 2024-08-10 14:02:58.175      98         2      0
#
#    missed
# 0       0
# 1       1
# 2       1
# 3       3
# 4       0
#
# [5 rows x 26 columns]

# %%
# new_df.drop(columns="charStats", inplace=True)
new_df.dropna()
new_df.head(5)
typing_metrixs_corr = new_df[["correct", "incorrect", "extra", "missed", "consistency", "acc", "wpm", "rawWpm", "mode2", "restartCount"]].corr()

# %%
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.1.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.53.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (162 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in /home/shad/Documents/challanges/.venv/lib/python3.10/site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/shad/Documents/challanges/.venv/lib/python3.10/site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-10.4.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/shad/Documents/challanges/.venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /home/shad/Documents/challanges/.venv/lib/python3.10/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /home/shad/Documents/challanges/.venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/shad/Documents/challanges/.venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/shad/Documents/challanges/.venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.1.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 551.0 kB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 588.7 kB/s eta 0:00:001m593.1 kB/s eta 0:00:01
# Using cached contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (305 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.53.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
# Using cached kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Using cached pillow-10.4.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.9.1.post1 pillow-10.4.0 pyparsing-3.1.2 seaborn-0.13.2
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="white")

# Generate a large random dataset
mask = np.triu(np.ones_like(typing_metrixs_corr, dtype=bool))

f, ax = plt.subplots(figsize=(6, 3))

cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(typing_metrixs_corr  , mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

sns.heatmap(typing_metrixs_corr, annot=False)
# Out:
# <Axes: >
